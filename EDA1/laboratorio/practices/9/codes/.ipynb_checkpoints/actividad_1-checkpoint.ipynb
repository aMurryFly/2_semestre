# %%
def funcion1():
    print("Ingrese la cantidad de metros: ")
    metros = input()
    millas= metros * 
    pies = metros * 
    print(La conversion es:)
    print(millas)
    print(pies)    
funcion1()

def funcion2():
    print("Ingrese la cantidad de millas: ")
    metros = input()
    millas= millas * 
    cm = millas * 
    print(La conversion es:)
    print(metros)
    print(cm)    
funcion2()


def main():
    print("Conversor de unidades")
    print("Ingrese que conversion quiere hacer")
    print("a) Metros a Millas/Pies")
    print("b) Millas a Metros/Centimetros ")
    opcion = input('')

        if opcion == 'a':
            funcion1
        
        if opcion == 'b':
            funcion2 

main()
# Out:
#   File "<ipython-input-6-5c598a9e3beb>", line 11
#     if opcion == 'a':
#     ^
# IndentationError: unexpected indent
